# %%
# Import the random module.
import random

# %%
random.randint(-90,90)
# Out:
# -39

# %%
random.random()
# Out:
# 0.28745539543909804

# %%
random_number = random.randint(-90, 89) + random.random()

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1

# %%
latitudes
# Out:
# [-55.22425055779497,
#  -60.41947111194273,
#  -16.180719334999615,
#  16.52785218886796,
#  -50.61867930736525,
#  88.07512646393944,
#  34.15070039163517,
#  -48.565989552966336,
#  -37.0916535636142,
#  -32.32533896751855]

# %%
random.randrange(-90,90, step=1)
# Out:
# -3

# %%
random.randrange(-90, 90, step=3)
# Out:
# -45

# %%
random.uniform(-90,90)
# Out:
# 5.55376459599664

# %%
# Import the NumPy module.
import numpy as np

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# -34.4552027347627

# %%
np.random.uniform(low=-90, high=90)
# Out:
# -48.557259900944665

# %%
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([ 65.11923698,  -2.38417242,  67.09233711,  72.52659525,
#        -29.47001146,   0.55566017,  49.28254978,  33.38711345,
#        -57.32449346, -18.03501396, -69.70323609,  78.55919762,
#         11.47040549,  73.68324962,  52.94862163, -36.88754634,
#         42.92798158,  41.26221484, -61.22268375, -33.4215344 ,
#         40.4377835 ,  74.98618977, -18.53108298,  -4.76765024,
#         39.4059684 ,  82.56470238, -53.38901202, -43.46463009,
#         80.8246567 ,  62.56795759, -89.69305199, -48.90366855,
#        -78.34832559,  81.8471695 , -13.14361291,   8.17835608,
#        -10.31052332,  -5.80509417,  -7.05683768,  10.68292081,
#          5.52576869, -31.02821236,  31.04921815,  75.17449367,
#         72.08566749,  27.84613075, -55.16165107, -76.89671195,
#        -12.22467001,  74.62848669])

# %%
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 15.2 µs ± 607 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.74 ms ± 71.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
def longitudes(size):
    longitudes = []
    x = 0
    while x < (size):
        random_long = random.randint(-180, 180) + random.random()
        longitudes.append(random_long)
        x += 1
    return longitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.7 ms ± 23 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# ??????????????????????????


def longitudes(size):
    longitudes = []
    
    for size in longitudes:
        random_long = random.randint(-180, 180) + random.random()
        longitudes.append(random_long)
       
    return longitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.67 ms ± 12.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
